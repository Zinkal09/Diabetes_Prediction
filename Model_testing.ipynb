# %%
# !pip install requests==2.32.3
# Out:
# Requirement already satisfied: requests==2.32.3 in c:\users\kaveni bhadresha\miniconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaveni bhadresha\miniconda3\lib\site-packages (from requests==2.32.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaveni bhadresha\miniconda3\lib\site-packages (from requests==2.32.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaveni bhadresha\miniconda3\lib\site-packages (from requests==2.32.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaveni bhadresha\miniconda3\lib\site-packages (from requests==2.32.3) (2025.4.26)

# %%
url = "http://127.0.0.1:5000/predict"

# %%
data = {
    "Pregnancies": 8,
    "Glucose": 100,
    "BloodPressure": 85,
    "SkinThickness": 0,
    "Insulin": 0,
    "BMI": 35,
    "DiabetesPedigreeFunction": 0.380,
    "Age": 51
}
# 8,99,84,0,0,35.4,0.388,50,0

# %%
# data={}

# %%
import requests
response = requests.post(url, json=data)
print(response)
print(response.json())
# Out:
# <Response [200]>
# {'prediction': 'No Diabetes'}
